# %%
from sympy import solve
from sympy import Symbol
from sympy import abc
import numpy as np

# %%
y, k, S_e, P = Symbol("y"), Symbol("k"), Symbol("S_e"), Symbol("P")
W, S, j, P_b = Symbol("W"), Symbol("S"), Symbol("j"), Symbol("P_b")
A_e, A_p, E, a = Symbol("A_e"), Symbol("A_p"), Symbol("E"), Symbol("a")
g, P_u, b, E_u = Symbol("g"), Symbol("P_u"), Symbol("b"), Symbol("E_u")
E_b, z, V, V_max = Symbol("E_b"), Symbol("z"), Symbol("V"), Symbol("V_max")
K_m, f = Symbol("K_m"), Symbol("f")
l = abc.lamda

# %%
def root_finder():
    eqn = -(z + l) * (
        (-k*S_e - (k/W)*S - l)*(-(j+a+l)*((V_max*K_m)/(V*(K_m+S)**2) -l) - (k*A_p)/(k*W)*(j+a)*P)
        - j*((k*S_e + k*S/W)*(V_max*K_m / (V*(K_m + S)**2) -l) + (A_p*k**2)/(V*W**2)*P*S)
        - (k*P/W) * ((k*S_e + k*S/W) * (A_p/V * (j+a)) - (j+a+l)*(A_p*k/(V*W) *S))
    )
    return solve(eqn, l, dict=True)

sol = root_finder()
for s in sol:
    print(s)
    print()
# Out:
# [{lamda: -0.00200000000000000}, {lamda: -1451.42104487229 - 0.e-23*I}, {lamda: -0.931054502701145 + 0.e-20*I}, {lamda: -0.399943323847921 - 0.e-20*I}]

# %%
# Params
a = 1
b = 1
A_p = 314
j = 10**2
K_d = 0.74
K_m = 2.5
k = j/K_d
V_max = 8.8 * 10**3
V = 523
W = 32
y = 0.000083
z = .002
f = 0.1
A_e = 47
g = 0.1
S_e = 10
P = 6.203405499080083e-06
S = 0.0007480237053453874
P_b = 8.299999999999973e-05
P_u = 0.04150000033571511

# %%
l1 = -z
l2 = -(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)/(3*(np.sqrt(-4*(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)**3 + (27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/((K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + 2*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**2)/2 + 27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(2*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(2*(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**(1/3)) - (np.sqrt(-4*(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)**3 + (27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/((K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + 2*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**2)/2 + 27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(2*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(2*(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**(1/3)/3 - (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)/(3*(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W))

l3 = -(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)/(3*(-1/2 - np.sqrt(3)*1j/2)*(np.sqrt(-4*(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)**3 + (27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/((K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + 2*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**2)/2 + 27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(2*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(2*(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**(1/3)) - (-1/2 - np.sqrt(3)*1j/2)*(np.sqrt(-4*(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)**3 + (27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/((K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + 2*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**2)/2 + 27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(2*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(2*(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**(1/3)/3 - (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)/(3*(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W))

l4 = -(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)/(3*(-1/2 + np.sqrt(3)*1j/2)*(np.sqrt(-4*(-3*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) + (K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**2/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**2)**3 + (27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/((K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) + 2*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)**3/(K_m**2*V*W + 2*K_m*S*V*W + S**2*V*W)**3)**2)/2 + 27*(-A_p*K_m**2*P*S*V*a*k - A_p*K_m**2*P*S*V*j*k + A_p*K_m**2*P*S*j*k**2 - A_p*K_m**2*P*S_e*V*W*a*k - A_p*K_m**2*P*S_e*V*W*j*k + A_p*K_m**2*P*S_e*W*a*k**2 + A_p*K_m**2*P*S_e*W*j*k**2 - 2*A_p*K_m*P*S**2*V*a*k - 2*A_p*K_m*P*S**2*V*j*k + 2*A_p*K_m*P*S**2*j*k**2 - 2*A_p*K_m*P*S*S_e*V*W*a*k - 2*A_p*K_m*P*S*S_e*V*W*j*k + 2*A_p*K_m*P*S*S_e*W*a*k**2 + 2*A_p*K_m*P*S*S_e*W*j*k**2 - A_p*P*S**3*V*a*k - A_p*P*S**3*V*j*k + A_p*P*S**3*j*k**2 - A_p*P*S**2*S_e*V*W*a*k - A_p*P*S**2*S_e*V*W*j*k + A_p*P*S**2*S_e*W*a*k**2 + A_p*P*S**2*S_e*W*j*k**2 - K_m*S*V_max*W*a*k - K_m*S_e*V_max*W**2*a*k)/(2*(K_m**2*V*W**2 + 2*K_m*S*V*W**2 + S**2*V*W**2)) - 9*(K_m**2*S*V*k + K_m**2*S_e*V*W*k + K_m**2*V*W*a + K_m**2*V*W*j + 2*K_m*S**2*V*k + 2*K_m*S*S_e*V*W*k + 2*K_m*S*V*W*a + 2*K_m*S*V*W*j - K_m*V_max*W + S**3*V*k + S**2*S_e*V*W*k + S**2*V*W*a + S**2*V*W*j)*(-A_p*K_m**2*P*S*k**2 - A_p*K_m**2*P*V*W*a - A_p*K_m**2*P*V*W*j - 2*A_p*K_m*P*S**2*k**2 - 2*A_p*K_m*P*S*V*W*a - 2*A_p*K_m*P*S*V*W*j - A_p*P*S**3*k**2 - A_p*P*S**2*V*W*a - A_p*P*S**2*V*W*j + K_m**2*S*V*W*a*k + K_m**2*S_e*V*W**2*a*k + 2*K_m*S**2*V*W*a*k + 2*K_m*S*S_e*V*W**2*a*k - K_m*S*V_max*W*k - K_m*S_e*V_max*W**2*k - K_m*V_max*W**2*a - K_m*V_max*W**2*j + S**3*V*W*a*k + S**2*S_e*V*W**2*a*k)/